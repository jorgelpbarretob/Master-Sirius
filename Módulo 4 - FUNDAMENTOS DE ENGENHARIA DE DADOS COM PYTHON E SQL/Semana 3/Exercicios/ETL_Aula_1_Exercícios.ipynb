# %% [markdown]
# # Exercício
#
# Faça a extração de alguma tabela da Wikipedia utilizando a biblioteca BeautifulSoup

# %%
# !pip install jupysql
# !pip install beautifulsoup4
# Out:
# Collecting jupysql
#   Downloading jupysql-0.10.4-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from jupysql) (3.9.0)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (from jupysql) (2.0.23)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.10/dist-packages (from jupysql) (0.4.4)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jupysql) (0.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from jupysql) (3.1.2)
# Requirement already satisfied: sqlglot>=11.3.7 in /usr/local/lib/python3.10/dist-packages (from jupysql) (17.16.2)
# Collecting ploomber-core>=0.2.7 (from jupysql)
#   Downloading ploomber_core-0.2.18-py3-none-any.whl (22 kB)
# Collecting jupysql-plugin (from jupysql)
#   Downloading jupysql_plugin-0.2.7-py3-none-any.whl (376 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.7/376.7 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from ploomber-core>=0.2.7->jupysql) (8.1.7)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ploomber-core>=0.2.7->jupysql) (6.0.1)
# Collecting posthog (from ploomber-core>=0.2.7->jupysql)
#   Downloading posthog-3.1.0-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->jupysql) (2.1.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->jupysql) (0.2.12)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->jupysql) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->jupysql) (3.0.1)
# Requirement already satisfied: requests<3.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.31.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog->ploomber-core>=0.2.7->jupysql) (1.16.0)
# Collecting monotonic>=1.5 (from posthog->ploomber-core>=0.2.7->jupysql)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog->ploomber-core>=0.2.7->jupysql)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.10/dist-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2023.11.17)
# Installing collected packages: monotonic, backoff, posthog, ploomber-core, jupysql-plugin, jupysql
# Successfully installed backoff-2.2.1 jupysql-0.10.4 jupysql-plugin-0.2.7 monotonic-1.6 ploomber-core-0.2.18 posthog-3.1.0
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import sqlite3

# %%
# Fazer requisição GET para a página da Wikipedia e obter o conteúdo HTML
url = "https://en.wikipedia.org/wiki/List_of_countries_by_beer_consumption_per_capita"
response = requests.get(url)
html = response.content

# Criar o objeto Beautiful Soup
soup = BeautifulSoup(html, "html.parser")

# Encontrar a tabela desejada na página (pode variar dependendo da página e dados que você deseja extrair)
table = soup.find_all("table", class_="wikitable")[0]

# Extrair os dados da tabela para uma lista
data = []
for row in table.find_all("tr"):
    cols = row.find_all("td")
    if cols:
        values = [col.text.strip() for col in cols]
        data.append(values)

# %%
data
# Out:
# [['Czech Republic\u202f*', '140.0', '', '1,498', '2020', '[2]'],
#  ['Austria\u202f*', '107.8', '0.2', '949', '2019', '[1]'],
#  ['Romania\u202f*', '100.3', '1.4', '1,956', '2019', '[1]'],
#  ['Germany\u202f*', '99.0', '-2.1', '8,160', '2019', '[1]'],
#  ['Poland\u202f*', '97.7', '-0.5', '3,713', '2019', '[1]'],
#  ['Namibia', '95.5', '14.2', '248', '2019', '[1]'],
#  ['Ireland', '92.9', '-2.9', '446', '2019', '[1]'],
#  ['Spain\u202f*', '88.8', '1.5', '4,119', '2019', '[1]'],
#  ['Croatia\u202f*', '85.5', '5.0', '351', '2019', '[1]'],
#  ['Latvia', '81.4', '4.6', '155', '2019', '[1]'],
#  ['Estonia\u202f*', '80.5', '7.9', '105', '2019', '[1]'],
#  ['Slovenia\u202f*', '80.0', '-0.2', '168', '2019', '[1]'],
#  ['Netherlands\u202f*', '79.3', '1.2', '1,357', '2019', '[1]'],
#  ['Bulgaria\u202f*', '78.7', '2.3', '551', '2019', '[1]'],
#  ['Panama\u202f*', '78.3', '1.5', '329', '2019', '[1]'],
#  ['Slovakia\u202f*', '76.1', '-0.9', '418', '2019', '[1]'],
#  ['Australia\u202f*', '75.1', '-1.2', '1,885', '2019', '[1]'],
#  ['Lithuania\u202f*', '74.4', '-2.1', '216', '2019', '[1]'],
#  ['Hungary\u202f*', '73.7', '-1.1', '715', '2019', '[1]'],
#  ['United States\u202f*', '72.7', '-0.8', '23,920', '2019', '[1]'],
#  ['Finland\u202f*', '72.0', '-3.2', '403', '2019', '[1]'],
#  ['Mexico\u202f*', '70.5', '1.8', '9,324', '2019', '[1]'],
#  ['United Kingdom\u202f*', '70.3', '-1.4', '4,712', '2019', '[1]'],
#  ['Bosnia and Herzegovina\u202f*', '68.6', '0.8', '240', '2019', '[1]'],
#  ['Gabon', '67.0', '-0.4', '141', '2019', '[1]'],
#  ['Belgium\u202f*', '65.9', '-1.0', '765', '2019', '[1]'],
#  ['New Zealand\u202f*', '61.0', '-1.6', '293', '2019', '[1]'],
#  ['South Africa\u202f*', '60.1', '1.1', '3,447', '2018', '[1]'],
#  ['Denmark\u202f*', '59.8', '0.2', '347', '2019', '[1]'],
#  ['Cambodia\u202f*', '59.2', '2.3', '976', '2019', '[1]'],
#  ['Brazil\u202f*', '58.4', '-1.6', '12,401', '2019', '[1]'],
#  ['Russia\u202f*', '57.7', '0.7', '8,306', '2019', '[1]'],
#  ['Switzerland\u202f*', '55.1', '-0.4', '474', '2019', '[1]'],
#  ['Portugal\u202f*', '54.9', '2.3', '565', '2019', '[1]'],
#  ['DR Congo', '54.8', '-2.2', '302', '2019', '[1]'],
#  ['Canada\u202f*', '53.5', '-2.1', '1,994', '2019', '[1]'],
#  ['Puerto Rico', '54.8', '-3.0', '203', '2018', '[1]'],
#  ['Serbia\u202f*', '54.7', '3.1', '481', '2018', ''],
#  ['Cyprus\u202f*', '47.0', '', '', '2021', '[3]'],
#  ['South Korea\u202f*', '39.4', '0.1', '2,022', '2019', '[1]'],
#  ['Vietnam\u202f*', '45.1', '', '2,600', '2020/21', '[4][5]'],
#  ['Japan\u202f*', '38.4', '-0.4', '4,869', '2019', '[1]'],
#  ['Laos', '41.4', '', '', '2015', '[6]'],
#  ['France\u202f*', '33', '', '', '2016', '[7]'],
#  ['Italy\u202f*', '31', '', '', '2016', '[8]'],
#  ['China\u202f*', '29', '', '43,266', '2018', '[9]'],
#  ['Thailand\u202f*', '27', '', '', '2015', '[6]'],
#  ['Taiwan\u202f*', '23.2', '', '', '2015', '[6]'],
#  ['Hong Kong\u202f*', '21.2', '', '159', '2018', '[10]'],
#  ['Singapore\u202f*', '20.9', '', '', '2015', '[6]'],
#  ['Israel\u202f*', '17.4', '', '', '2013', '[11]'],
#  ['Turkey\u202f*', '10.9', '', '', '2020', '[12]'],
#  ['Kenya\u202f*', '12', '', '', '', '[13]'],
#  ['Myanmar\u202f*', '11.3', '', '', '2015', '[6]'],
#  ['Uzbekistan', '11', '', '', '', '[14]'],
#  ['Papua New Guinea', '10.9', '', '', '2015', '[6]'],
#  ['Tanzania\u202f*', '8', '', '', '', '[13]'],
#  ['Uganda', '6', '', '', '', '[13]'],
#  ['Malaysia\u202f*', '5.8', '', '', '2015', '[6]'],
#  ['Sri Lanka\u202f*', '2', '', '50', '', '[15]'],
#  ['India\u202f*', '2', '', '', '2015', '[6]'],
#  ['Indonesia\u202f*', '0.7', '', '', '2015', '[6]']]

# %% [markdown]
# #Transformação

# %%
for i in range(len(data)):
    # Remover caracteres indesejados no nome do país
    data[i][0] = data[i][0].replace('\u202f*', '').strip()

    # Substituir strings vazias por None (ou outro valor de sua escolha)
    data[i] = [None if x == '' else x for x in data[i]]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                  0      1     2      3     4     5
# 0   Czech Republic  140.0  None  1,498  2020   [2]
# 1          Austria  107.8   0.2    949  2019   [1]
# 2          Romania  100.3   1.4  1,956  2019   [1]
# 3          Germany   99.0  -2.1  8,160  2019   [1]
# 4           Poland   97.7  -0.5  3,713  2019   [1]
# ..             ...    ...   ...    ...   ...   ...
# 57          Uganda      6  None   None  None  [13]
# 58        Malaysia    5.8  None   None  2015   [6]
# 59       Sri Lanka      2  None     50  None  [15]
# 60           India      2  None   None  2015   [6]
# 61       Indonesia    0.7  None   None  2015   [6]
#
# [62 rows x 6 columns]

# %%
df.columns = ["Country", "Consumption per capita (litres per year)", "Total national consumption (million litres per year)", "2018 change (litres per year)", "Year", "Sources"]

# %%
df
# Out:
#            Country Consumption per capita (litres per year)  \
# 0   Czech Republic                                    140.0
# 1          Austria                                    107.8
# 2          Romania                                    100.3
# 3          Germany                                     99.0
# 4           Poland                                     97.7
# ..             ...                                      ...
# 57          Uganda                                        6
# 58        Malaysia                                      5.8
# 59       Sri Lanka                                        2
# 60           India                                        2
# 61       Indonesia                                      0.7
#
#    Total national consumption (million litres per year)  \
# 0                                                None
# 1                                                 0.2
# 2                                                 1.4
# 3                                                -2.1
# 4                                                -0.5
# ..                                                ...
# 57                                               None
# 58                                               None
# 59                                               None
# 60                                               None
# 61                                               None
#
#    2018 change (litres per year)  Year Sources
# 0                          1,498  2020     [2]
# 1                            949  2019     [1]
# 2                          1,956  2019     [1]
# 3                          8,160  2019     [1]
# 4                          3,713  2019     [1]
# ..                           ...   ...     ...
# 57                          None  None    [13]
# 58                          None  2015     [6]
# 59                            50  None    [15]
# 60                          None  2015     [6]
# 61                          None  2015     [6]
#
# [62 rows x 6 columns]

# %%
df.set_index('Country', inplace=True)

# %%
df
# Out:
#                Consumption per capita (litres per year)  \
# Country
# Czech Republic                                    140.0
# Austria                                           107.8
# Romania                                           100.3
# Germany                                            99.0
# Poland                                             97.7
# ...                                                 ...
# Uganda                                                6
# Malaysia                                            5.8
# Sri Lanka                                             2
# India                                                 2
# Indonesia                                           0.7
#
#                Total national consumption (million litres per year)  \
# Country
# Czech Republic                                               None
# Austria                                                       0.2
# Romania                                                       1.4
# Germany                                                      -2.1
# Poland                                                       -0.5
# ...                                                           ...
# Uganda                                                       None
# Malaysia                                                     None
# Sri Lanka                                                    None
# India                                                        None
# Indonesia                                                    None
#
#                2018 change (litres per year)  Year Sources
# Country
# Czech Republic                         1,498  2020     [2]
# Austria                                  949  2019     [1]
# Romania                                1,956  2019     [1]
# Germany                                8,160  2019     [1]
# Poland                                 3,713  2019     [1]
# ...                                      ...   ...     ...
# Uganda                                  None  None    [13]
# Malaysia                                None  2015     [6]
# Sri Lanka                                 50  None    [15]
# India                                   None  2015     [6]
# Indonesia                               None  2015     [6]
#
# [62 rows x 5 columns]

# %% [markdown]
# # Carregamento

# %%
# %load_ext sql
# Out:
# Deploy AI and data apps for free on Ploomber Cloud! Learn more: https://docs.cloud.ploomber.io/en/latest/quickstart/signup.html

# %%
# %%sql sqlite://
# Out:
# Connecting to 'sqlite://'

# %%
# %sql --persist df
# Out:
# Running query in 'sqlite://'
# Success! Persisted df to the database.

# %%
# %%sql
#
# select * from df
# Out:
# Running query in 'sqlite://'
# +----------------+------------------------------------------+------------------------------------------------------+-------------------------------+------+---------+
# |    Country     | Consumption per capita (litres per year) | Total national consumption (million litres per year) | 2018 change (litres per year) | Year | Sources |
# +----------------+------------------------------------------+------------------------------------------------------+-------------------------------+------+---------+
# | Czech Republic |                  140.0                   |                         None                         |             1,498             | 2020 |   [2]   |
# |    Austria     |                  107.8                   |                         0.2                          |              949              | 2019 |   [1]   |
# |    Romania     |                  100.3                   |                         1.4                          |             1,956             | 2019 |   [1]   |
# |    Germany     |                   99.0                   |                         -2.1                         |             8,160             | 2019 |   [1]   |
# |     Poland     |                   97.7                   |                         -0.5                         |             3,713             | 2019 |   [1]   |
# |    Namibia     |                   95.5                   |                         14.2                         |              248              | 2019 |   [1]   |
# |    Ireland     |                   92.9                   |                         -2.9                         |              446              | 2019 |   [1]   |
# |     Spain      |                   88.8                   |                         1.5                          |             4,119             | 2019 |   [1]   |
# |    Croatia     |                   85.5                   |                         5.0                          |              351              | 2019 |   [1]   |
# |     Latvia     |                   81.4                   |                         4.6                          |              155              | 2019 |   [1]   |
# +----------------+------------------------------------------+------------------------------------------------------+-------------------------------+------+---------+
# Truncated to displaylimit of 10.
